# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\jayas\Downloads\Ds Datasets\FIFA.csv")

# %%
df.head(1)
# Out:
#    Unnamed: 0      ID      Name  Age  \
# 0           0  158023  L. Messi   31
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
#
# [1 rows x 89 columns]

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.distplot(df.Age,bins = 12)
sns.set_style('dark')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.histplot(df.Age,bins = 12)

# %%
df.info()

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.kdeplot(data = df, x = 'Age',hue = 'Preferred Foot',shade = True)

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.countplot(data = df,x = 'Preferred Foot')

# %%
plt.title('FIFA-19 Players Data Analysis')
plt.figure(figsize=(10,10))
vis = sns.countplot(data = df,x='Preferred Foot',hue = 'Real Face')
plt.savefig('vis4.png')

# %%
df['International Reputation'].nunique()
# Out:
# 5

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.stripplot(data = df,x = 'International Reputation',y = 'Potential',palette = 'Set2',hue = 'Preferred Foot',dodge = True)

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.boxplot(data = df,x = 'Potential')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.boxplot(data = df,y = 'Potential',x ='International Reputation',palette = 'Set2',hue = 'Preferred Foot')

# %%
plt.title('FIFA-19 Players Data Analysis')

vis = sns.violinplot(data = df,y = 'Potential',x ='International Reputation',palette = 'Set3',hue = 'Preferred Foot',split = True)

# %%
 plt.title('FIFA-19 Players Data Analysis')
vis = sns.pointplot(data = df,y = 'Potential',x ='International Reputation',palette = 'Set2',hue = 'Preferred Foot',markers = ['o','x'],dodge = True)

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.barplot(data = df,y = 'Potential',x ='International Reputation',palette = 'Set2',hue = 'Preferred Foot',capsize = 0.2)

# %%
df['Overall'].nunique()
# Out:
# 48

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.regplot(data = df,x = 'Overall',y = 'Potential',color = 'g',marker = '+')

# %%
plt.title('FIFA-19 Players Data Analysis')
plt.figure(figsize=(10,10))
vis = sns.scatterplot(x = 'Height',y = 'Weight',data = df,hue = 'Preferred Foot')

# %%
df.info()

# %%
df['Stamina'].nunique()
# Out:
# 85

# %%
df['Strength'].nunique()
# Out:
# 74

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.lineplot(x ='Stamina', y = 'Strength',data= df,hue = 'Preferred Foot')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.regplot(x ='International Reputation', y = 'Potential',data= df)

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.lmplot(x = 'Overall', y = 'Potential',data = df,palette = 'Set2',hue = 'Preferred Foot')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.lmplot(x = 'Overall', y = 'Potential',data = df,palette = 'Set2',col = 'Preferred Foot')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis1 = sns.FacetGrid(df,col = 'International Reputation')
vis1 = vis1.map(plt.scatter,'Potential','Overall')
plt.savefig('vis1.png')

# %%
df.info()

# %%
arr = df[['Age', 'Potential', 'Strength', 'Stamina', 'Preferred Foot']]

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.PairGrid(arr,hue = 'Preferred Foot')
vis = vis.map_diag(plt.hist,color = 'g')
vis = vis.map_offdiag(plt.scatter)
plt.savefig('vis3.png')

# %%
plt.title('FIFA-19 Players Data Analysis')
vis = sns.jointplot(x = 'Potential',y = 'Overall',data = df,color = 'g',markers = '+')
